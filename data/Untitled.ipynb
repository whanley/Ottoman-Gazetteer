# %%
import pandas as pd

# %%
gaz = pd.read_csv('ottgaz.tsv',sep='\t')

# %%
gaz.head()
# Out:
#     Placename@tr  ottgaz_id Placename@ott Placename_2@tr Placename_2@ott  \
# 0          A’YUC        NaN         اعيوج            NaN             NaN
# 1       A’ZAMİYE        NaN        اعظميه            NaN             NaN
# 2          A’ZAZ        NaN         اعزاز            NaN             NaN
# 3   A’ZAZ FELLAH        NaN     اعزازفلاح            NaN             NaN
# 4  A’ZAZ TÜRKMEN        NaN   اعزازترکمان            NaN             NaN
#
#   Placename_3@tr Placename_4@tr Placename_5@tr Placename_notes@tr Place_type  \
# 0            NaN            NaN            NaN                NaN     Region
# 1            NaN            NaN            NaN                NaN     Region
# 2            NaN            NaN            NaN                NaN     Region
# 3            NaN            NaN            NaN                NaN     Region
# 4            NaN            NaN            NaN                NaN     Region
#
# ...
