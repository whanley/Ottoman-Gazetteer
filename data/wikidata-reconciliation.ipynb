# %%
import pandas as pd

# %%
gaz = pd.read_csv('osmanli-yer-adlari.tsv',sep='\t')

# %%
gaz.head()
# Out:
#     Placename@tr Placename@ott Placename_2@tr Placename_3@tr Placename_4@tr  \
# 0          A’YUC         اعيوج            NaN            NaN            NaN
# 1       A’ZAMİYE        اعظميه            NaN            NaN            NaN
# 2          A’ZAZ         اعزاز            NaN            NaN            NaN
# 3   A’ZAZ FELLAH     اعزازفلاح            NaN            NaN            NaN
# 4  A’ZAZ TÜRKMEN   اعزازترکمان            NaN            NaN            NaN
#
#   Placename_5@tr Placename_notes@tr Wikidata_url Admin_unit_1  \
# 0            NaN                NaN          NaN       Nahiye
# 1            NaN                NaN          NaN         Kaza
# 2            NaN                NaN          NaN       Nahiye
# 3            NaN                NaN          NaN       Nahiye
# 4            NaN                NaN          NaN         Kaza
#
#   Admin_unit_1_year      ...      Admin_unit_11_year Belongs_to_11-2  \
# 0               NaN      ...                     NaN             NaN
# 1           18. yy.      ...                     NaN             NaN
# 2              1517      ...                     NaN             NaN
# 3              1865      ...                     NaN             NaN
# 4           19. yy.      ...                     NaN             NaN
#
#   Belongs_to_11-1 Admin_unit_12 Belongs_to_12 Admin_unit_13 Belongs_to_13  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
#
#   Admin_unit_14 Admin_unit_14_year Belongs_to_14
# 0           NaN                NaN           NaN
# 1           NaN                NaN           NaN
# 2           NaN                NaN           NaN
# 3           NaN                NaN           NaN
# 4           NaN                NaN           NaN
#
# [5 rows x 76 columns]

# %%
gaz[gaz.Wikidata_url.notnull()].head()
# Out:
#    Placename@tr Placename@ott Placename_2@tr Placename_3@tr Placename_4@tr  \
# 6        ABADAN        عبادان            NaN            NaN            NaN
# 9         ABANO         آبانو            NaN            NaN            NaN
# 17         ABHA          ابها            NaN            NaN            NaN
# 19        ABONİ         آبونی            NaN            NaN            NaN
# 38        ACYUD         آجيود          ADJUD            NaN            NaN
#
#    Placename_5@tr Placename_notes@tr                           Wikidata_url  \
# 6             NaN                NaN   https://www.wikidata.org/wiki/Q63049
# 9             NaN                NaN   https://www.wikidata.org/wiki/Q34603
# 17            NaN                NaN  https://www.wikidata.org/wiki/Q190948
# 19            NaN                NaN  https://www.wikidata.org/wiki/Q480421
# 38            NaN                NaN  https://www.wikidata.org/wiki/Q357784
#
#       Admin_unit_1 Admin_unit_1_year      ...      Admin_unit_11_year  \
# 6            Şehir               NaN      ...                     NaN
# 9            Şehir               NaN      ...                     NaN
# 17  Sancak merkezi               NaN      ...                     NaN
# 19           Şehir               NaN      ...                     NaN
# 38           Şehir               NaN      ...                     NaN
#
#    Belongs_to_11-2 Belongs_to_11-1 Admin_unit_12 Belongs_to_12 Admin_unit_13  \
# 6              NaN             NaN           NaN           NaN           NaN
# 9              NaN             NaN           NaN           NaN           NaN
# 17             NaN             NaN           NaN           NaN           NaN
# 19             NaN             NaN           NaN           NaN           NaN
# 38             NaN             NaN           NaN           NaN           NaN
#
#    Belongs_to_13 Admin_unit_14 Admin_unit_14_year Belongs_to_14
# 6            NaN           NaN                NaN           NaN
# 9            NaN           NaN                NaN           NaN
# 17           NaN           NaN                NaN           NaN
# 19           NaN           NaN                NaN           NaN
# 38           NaN           NaN                NaN           NaN
#
# [5 rows x 76 columns]

# %%
import re

# %%
re.sub(r'wiki\/(.+)$',r'wiki/Special:EntityData/\1.json','https://www.wikidata.org/wiki/Q42')
# Out:
# 'https://www.wikidata.org/wiki/Special:EntityData/Q42.json'

# %%
gaz['wikidata_json'] = gaz.Wikidata_url.replace(r'wiki\/(.+)$',r'wiki/Special:EntityData/\1.json',regex=True)

# %%
test = gaz[gaz.wikidata_json.notnull()].wikidata_json[6]

# %%
import requests

# %%
response = requests.get(test)

# %%
response.json()
# Out:
# {'entities': {'Q63049': {'aliases': {'ar': [{'language': 'ar',
#       'value': 'آبادان'},
#      {'language': 'ar', 'value': 'ميناء عبادان'},
#      {'language': 'ar', 'value': 'عبدان'}],
#     'be': [{'language': 'be', 'value': 'Абадан'}],
#     'ca': [{'language': 'ca', 'value': 'Abbadan'}],
#     'cs': [{'language': 'cs', 'value': 'Abadán'}],
#     'en': [{'language': 'en', 'value': 'Ābadān'}],
#     'eo': [{'language': 'eo', 'value': 'Abdano'}],
#     'es': [{'language': 'es', 'value': 'Ābadan'},
#      {'language': 'es', 'value': 'Abadān'},
#      {'language': 'es', 'value': 'A ba-da-n'},
#      {'language': 'es', 'value': 'Ābadān'},
#      {'language': 'es', 'value': 'Abadan'},
#      {'language': 'es', 'value': 'A-ba-da-n'},
#      {'language': 'es', 'value': 'Abādān'},
#      {'language': 'es', 'value': 'A ba da-n'},
#      {'language': 'es', 'value': 'Ābādān'},
#      {'language': 'es', 'value': 'A ba da n'}],
#     'fa': [{'language': 'fa', 'value': 'عبادان'},
#      {'language': 'fa', 'value': 'مسجد رانگونی\u200cها'},
#      {'language': 'fa', 'value': 'ابادان'}],
#     'fi': [{'language': 'fi', 'value': 'Abbadan'}],
#     'gl': [{'language': 'gl', 'value': 'Abadán'}],
#     'he': [{'language': 'he', 'value': 'אבדן'},
#      {'language': 'he', 'value': 'אבדאן'},
#      {'language': 'he', 'value': 'אבאדן'}],
#     'ja': [{'language': 'ja', 'value': 'アバダン'},
#      {'language': 'ja', 'value': 'アバダーン'}],
#     'lv': [{'language': 'lv', 'value': 'Abadan'},
#      {'language': 'lv', 'value': 'Abadana'}],
#     'pt': [{'language': 'pt', 'value': 'Abadã'}],
#     'sk': [{'language': 'sk', 'value': 'Abadan'}],
#     'sr': [{'language': 'sr', 'value': 'آبادان'}],
#     'sv': [{'language': 'sv', 'value': "Abada'n"}],
#     'zh': [{'language': 'zh', 'value': '提罗卢和国'}]},
#    'claims': {'P131': [{'id': 'q63049$7040C9B6-227C-42F9-BAE3-B642B5FB22C7',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 4812565}},
#        'property': 'P131',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '527e37d09f6b28f81ecbcbfa85dc4b79d783b297',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 48952}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': '7eb64cf9621d34c54fd4bd040ed4b61a88c4a1a0',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 328}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P1343': [{'id': 'Q63049$9DAC688E-A1A2-47D9-9267-30C5E9BD1C43',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 2657718}},
#        'property': 'P1343',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q63049$dacbb2f7-4fa3-263c-1762-62d5005e1176',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 22074611}},
#        'property': 'P1343',
#        'snaktype': 'value'},
#       'qualifiers': {'P304': [{'datatype': 'string',
#          'datavalue': {'type': 'string', 'value': '224'},
#          'hash': '3572e5516d561866586a4a6d5ddfc04089755e90',
#          'property': 'P304',
#          'snaktype': 'value'}],
#        'P958': [{'datatype': 'string',
#          'datavalue': {'type': 'string', 'value': 'Abadan'},
#          'hash': '591965e94e2906ce15fb32a920267d10f1d191e4',
#          'property': 'P958',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P958', 'P304'],
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1417': [{'id': 'Q63049$62487FC5-E077-42ED-A05B-9127261FC824',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'place/Abadan'},
#        'property': 'P1417',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1464': [{'id': 'Q63049$9e966444-4493-e938-7285-af137f2dd6cf',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 8725419}},
#        'property': 'P1464',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1566': [{'id': 'Q63049$1E5056D0-C417-4BD5-9FF3-F648C65D44C2',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '145459'},
#        'property': 'P1566',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'd6193e4d78598db1a6aaa453fface1553022f1f2',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 830106}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P1584': [{'id': 'Q63049$38829051-D019-4A6D-92D4-782CEC043CE1',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '211425280'},
#        'property': 'P1584',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P17': [{'id': 'q63049$8E08D436-2D73-41E8-8F08-23BDE62F63D1',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 794}},
#        'property': 'P17',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '527e37d09f6b28f81ecbcbfa85dc4b79d783b297',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 48952}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P18': [{'id': 'Q63049$0200650E-F59C-4937-9337-245541B08EBA',
#       'mainsnak': {'datatype': 'commonsMedia',
#        'datavalue': {'type': 'string', 'value': 'Abadan the city of Oil.jpg'},
#        'property': 'P18',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q63049$E04C8F00-C952-475C-8A4B-C7B43A2CDBD2',
#       'mainsnak': {'datatype': 'commonsMedia',
#        'datavalue': {'type': 'string', 'value': 'Abadanraffinerie.jpg'},
#        'property': 'P18',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '473eaef2829a3b999a3002bb35c7f5b896c955bf',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 53464}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P1997': [{'id': 'Q63049$4fe909c8-4053-a75b-04ba-4b9ccde8cb1f',
#       'mainsnak': {'datatype': 'string',
#        'datavalue': {'type': 'string', 'value': '103762042995585'},
#        'property': 'P1997',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P214': [{'id': 'Q63049$33A212E8-C4F2-4AD3-B0D7-419C68588280',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '159458578'},
#        'property': 'P214',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'd6b4bc80e47def2fab91836d81e1db62c640279c',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 54919}},
#            'property': 'P248',
#            'snaktype': 'value'}],
#          'P813': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2015-08-02T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P813',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P248', 'P813']}],
#       'type': 'statement'}],
#     'P31': [{'id': 'q63049$BE9428C3-44C0-416A-BC1F-BC7EE2D4133C',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 515}},
#        'property': 'P31',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '527e37d09f6b28f81ecbcbfa85dc4b79d783b297',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 48952}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P361': [{'id': 'q63049$D1E477A1-6F52-49CA-A0E1-1BF05C5C8775',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 1279180}},
#        'property': 'P361',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '527e37d09f6b28f81ecbcbfa85dc4b79d783b297',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 48952}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P373': [{'id': 'q63049$B2B57E2D-597C-47B7-AA18-EE42C5D7AB64',
#       'mainsnak': {'datatype': 'string',
#        'datavalue': {'type': 'string', 'value': 'Abadan'},
#        'property': 'P373',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P473': [{'id': 'q63049$48f5e44c-49c0-1197-64d7-e27bf0d1e8ce',
#       'mainsnak': {'datatype': 'string',
#        'datavalue': {'type': 'string', 'value': '0631'},
#        'property': 'P473',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P625': [{'id': 'q63049$9ADDF74D-821D-4143-A585-60C7C084BAD9',
#       'mainsnak': {'datatype': 'globe-coordinate',
#        'datavalue': {'type': 'globecoordinate',
#         'value': {'altitude': None,
#          'globe': 'http://www.wikidata.org/entity/Q2',
#          'latitude': 30.35,
#          'longitude': 48.283333333333,
#          'precision': 0.016666666666667}},
#        'property': 'P625',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 206855}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P646': [{'id': 'Q63049$916D110F-F6B3-4CA6-8410-F85353C84814',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '/m/0vck'},
#        'property': 'P646',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'af38848ab5d9d9325cffd93a5ec656cc6ca889ed',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'numeric-id': 15241312}},
#            'property': 'P248',
#            'snaktype': 'value'}],
#          'P577': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2013-10-28T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P577',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P248', 'P577']}],
#       'type': 'statement'}],
#     'P910': [{'id': 'Q63049$342D9646-8432-4144-8E0D-EA001EDE6DD9',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'numeric-id': 8874619}},
#        'property': 'P910',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}]},
#    'descriptions': {'de': {'language': 'de', 'value': 'Stadt in Iran'},
#     'en': {'language': 'en', 'value': 'city in Iran'},
#     'es': {'language': 'es', 'value': 'ciudad de Irán'},
#     'fa': {'language': 'fa', 'value': 'شهری بندری در جنوب ایران'},
#     'fr': {'language': 'fr', 'value': 'commune iranienne'},
#     'nl': {'language': 'nl', 'value': 'stad in Iran'},
#     'ru': {'language': 'ru', 'value': 'город в Иране'}},
#    'id': 'Q63049',
#    'labels': {'ar': {'language': 'ar', 'value': 'عبادان'},
#     'arz': {'language': 'arz', 'value': 'ابادان'},
#     'az': {'language': 'az', 'value': 'Abadan'},
#     'be': {'language': 'be', 'value': 'Горад Абадан'},
#     'be-tarask': {'language': 'be-tarask', 'value': 'Абадан'},
#     'bg': {'language': 'bg', 'value': 'Абадан'},
#     'ca': {'language': 'ca', 'value': 'Abadan'},
#     'co': {'language': 'co', 'value': 'Abadan'},
#     'cs': {'language': 'cs', 'value': 'Ábádán'},
#     'cv': {'language': 'cv', 'value': 'Абадан'},
#     'da': {'language': 'da', 'value': 'Abadan'},
#     'de': {'language': 'de', 'value': 'Abadan'},
#     'diq': {'language': 'diq', 'value': 'Abadan'},
#     'el': {'language': 'el', 'value': 'Αμπαντάν'},
#     'en': {'language': 'en', 'value': 'Abadan'},
#     'eo': {'language': 'eo', 'value': 'Abadano'},
#     'es': {'language': 'es', 'value': 'Abadán'},
#     'et': {'language': 'et', 'value': 'Ābādān'},
#     'eu': {'language': 'eu', 'value': 'Abadan'},
#     'fa': {'language': 'fa', 'value': 'آبادان'},
#     'fi': {'language': 'fi', 'value': 'Abadan'},
#     'fr': {'language': 'fr', 'value': 'Abadan'},
#     'gl': {'language': 'gl', 'value': 'Abadán - آبادان'},
#     'he': {'language': 'he', 'value': 'אבאדאן'},
#     'hi': {'language': 'hi', 'value': 'अबादान'},
#     'hr': {'language': 'hr', 'value': 'Abadan'},
#     'hu': {'language': 'hu', 'value': 'Ábádán'},
#     'hy': {'language': 'hy', 'value': 'Աբադան'},
#     'id': {'language': 'id', 'value': 'Abadan'},
#     'it': {'language': 'it', 'value': 'Abadan'},
#     'ja': {'language': 'ja', 'value': 'アーバーダーン'},
#     'ka': {'language': 'ka', 'value': 'აბადანი'},
#     'ko': {'language': 'ko', 'value': '아바단'},
#     'lt': {'language': 'lt', 'value': 'Abadanas'},
#     'lv': {'language': 'lv', 'value': 'Abadāna'},
#     'mg': {'language': 'mg', 'value': 'Abadan, Iran'},
#     'nb': {'language': 'nb', 'value': 'Abadan'},
#     'nl': {'language': 'nl', 'value': 'Abadan'},
#     'nn': {'language': 'nn', 'value': 'Abadan'},
#     'oc': {'language': 'oc', 'value': 'Abadan'},
#     'pa': {'language': 'pa', 'value': 'ਆਬਾਦਾਨ'},
#     'pl': {'language': 'pl', 'value': 'Abadan'},
#     'pnb': {'language': 'pnb', 'value': 'آبادان'},
#     'pt': {'language': 'pt', 'value': 'Abadan'},
#     'ro': {'language': 'ro', 'value': 'Abadan'},
#     'ru': {'language': 'ru', 'value': 'Абадан'},
#     'rup': {'language': 'rup', 'value': 'Abadan'},
#     'sco': {'language': 'sco', 'value': 'Abadan'},
#     'sh': {'language': 'sh', 'value': 'Abadan'},
#     'sk': {'language': 'sk', 'value': 'Ábádán'},
#     'sl': {'language': 'sl', 'value': 'Abadan'},
#     'sq': {'language': 'sq', 'value': 'Abadan'},
#     'sr': {'language': 'sr', 'value': 'Абадан'},
#     'sv': {'language': 'sv', 'value': 'Abadan'},
#     'tg': {'language': 'tg', 'value': 'Ободон'},
#     'tl': {'language': 'tl', 'value': 'Abadan'},
#     'tr': {'language': 'tr', 'value': 'Abadan'},
#     'uk': {'language': 'uk', 'value': 'Абадан'},
#     'ur': {'language': 'ur', 'value': 'آبادان'},
#     'uz': {'language': 'uz', 'value': 'Obodon'},
#     'vi': {'language': 'vi', 'value': 'Abadan'},
#     'war': {'language': 'war', 'value': 'Abadan'},
#     'zh': {'language': 'zh', 'value': '阿巴丹'}},
#    'lastrevid': 324966151,
#    'modified': '2016-04-24T15:49:13Z',
#    'ns': 0,
#    'pageid': 65791,
#    'sitelinks': {'arwiki': {'badges': [],
#      'site': 'arwiki',
#      'title': 'عبادان',
#      'url': 'https://ar.wikipedia.org/wiki/%D8%B9%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'arzwiki': {'badges': [],
#      'site': 'arzwiki',
#      'title': 'ابادان',
#      'url': 'https://arz.wikipedia.org/wiki/%D8%A7%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'azwiki': {'badges': [],
#      'site': 'azwiki',
#      'title': 'Abadan',
#      'url': 'https://az.wikipedia.org/wiki/Abadan'},
#     'be_x_oldwiki': {'badges': [],
#      'site': 'be_x_oldwiki',
#      'title': 'Абадан',
#      'url': 'https://be-tarask.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'bewiki': {'badges': [],
#      'site': 'bewiki',
#      'title': 'Горад Абадан',
#      'url': 'https://be.wikipedia.org/wiki/%D0%93%D0%BE%D1%80%D0%B0%D0%B4_%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'bgwiki': {'badges': [],
#      'site': 'bgwiki',
#      'title': 'Абадан',
#      'url': 'https://bg.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'cawiki': {'badges': [],
#      'site': 'cawiki',
#      'title': 'Abadan',
#      'url': 'https://ca.wikipedia.org/wiki/Abadan'},
#     'cowiki': {'badges': [],
#      'site': 'cowiki',
#      'title': 'Abadan (Iranu)',
#      'url': 'https://co.wikipedia.org/wiki/Abadan_(Iranu)'},
#     'cswiki': {'badges': [],
#      'site': 'cswiki',
#      'title': 'Ábádán',
#      'url': 'https://cs.wikipedia.org/wiki/%C3%81b%C3%A1d%C3%A1n'},
#     'cvwiki': {'badges': [],
#      'site': 'cvwiki',
#      'title': 'Абадан',
#      'url': 'https://cv.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'dawiki': {'badges': [],
#      'site': 'dawiki',
#      'title': 'Abadan',
#      'url': 'https://da.wikipedia.org/wiki/Abadan'},
#     'dewiki': {'badges': [],
#      'site': 'dewiki',
#      'title': 'Abadan',
#      'url': 'https://de.wikipedia.org/wiki/Abadan'},
#     'elwiki': {'badges': [],
#      'site': 'elwiki',
#      'title': 'Αμπαντάν',
#      'url': 'https://el.wikipedia.org/wiki/%CE%91%CE%BC%CF%80%CE%B1%CE%BD%CF%84%CE%AC%CE%BD'},
#     'enwiki': {'badges': [],
#      'site': 'enwiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://en.wikipedia.org/wiki/Abadan,_Iran'},
#     'enwikivoyage': {'badges': [],
#      'site': 'enwikivoyage',
#      'title': 'Abadan',
#      'url': 'https://en.wikivoyage.org/wiki/Abadan'},
#     'eowiki': {'badges': [],
#      'site': 'eowiki',
#      'title': 'Abadano',
#      'url': 'https://eo.wikipedia.org/wiki/Abadano'},
#     'eswiki': {'badges': [],
#      'site': 'eswiki',
#      'title': 'Abadán',
#      'url': 'https://es.wikipedia.org/wiki/Abad%C3%A1n'},
#     'etwiki': {'badges': [],
#      'site': 'etwiki',
#      'title': 'Ābādān',
#      'url': 'https://et.wikipedia.org/wiki/%C4%80b%C4%81d%C4%81n'},
#     'euwiki': {'badges': [],
#      'site': 'euwiki',
#      'title': 'Abadan',
#      'url': 'https://eu.wikipedia.org/wiki/Abadan'},
#     'fawiki': {'badges': [],
#      'site': 'fawiki',
#      'title': 'آبادان',
#      'url': 'https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'fawikiquote': {'badges': [],
#      'site': 'fawikiquote',
#      'title': 'آبادان',
#      'url': 'https://fa.wikiquote.org/wiki/%D8%A2%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'fawikivoyage': {'badges': [],
#      'site': 'fawikivoyage',
#      'title': 'آبادان',
#      'url': 'https://fa.wikivoyage.org/wiki/%D8%A2%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'fiwiki': {'badges': [],
#      'site': 'fiwiki',
#      'title': 'Abadan',
#      'url': 'https://fi.wikipedia.org/wiki/Abadan'},
#     'frwiki': {'badges': [],
#      'site': 'frwiki',
#      'title': 'Abadan',
#      'url': 'https://fr.wikipedia.org/wiki/Abadan'},
#     'glwiki': {'badges': [],
#      'site': 'glwiki',
#      'title': 'Abadan',
#      'url': 'https://gl.wikipedia.org/wiki/Abadan'},
#     'hewiki': {'badges': [],
#      'site': 'hewiki',
#      'title': 'אבאדאן',
#      'url': 'https://he.wikipedia.org/wiki/%D7%90%D7%91%D7%90%D7%93%D7%90%D7%9F'},
#     'hiwiki': {'badges': [],
#      'site': 'hiwiki',
#      'title': 'अबादान',
#      'url': 'https://hi.wikipedia.org/wiki/%E0%A4%85%E0%A4%AC%E0%A4%BE%E0%A4%A6%E0%A4%BE%E0%A4%A8'},
#     'hrwiki': {'badges': [],
#      'site': 'hrwiki',
#      'title': 'Abadan',
#      'url': 'https://hr.wikipedia.org/wiki/Abadan'},
#     'huwiki': {'badges': [],
#      'site': 'huwiki',
#      'title': 'Ábádán',
#      'url': 'https://hu.wikipedia.org/wiki/%C3%81b%C3%A1d%C3%A1n'},
#     'hywiki': {'badges': [],
#      'site': 'hywiki',
#      'title': 'Աբադան (Իրան)',
#      'url': 'https://hy.wikipedia.org/wiki/%D4%B1%D5%A2%D5%A1%D5%A4%D5%A1%D5%B6_(%D4%BB%D6%80%D5%A1%D5%B6)'},
#     'idwiki': {'badges': [],
#      'site': 'idwiki',
#      'title': 'Abadan',
#      'url': 'https://id.wikipedia.org/wiki/Abadan'},
#     'itwiki': {'badges': [],
#      'site': 'itwiki',
#      'title': 'Abadan',
#      'url': 'https://it.wikipedia.org/wiki/Abadan'},
#     'jawiki': {'badges': [],
#      'site': 'jawiki',
#      'title': 'アーバーダーン',
#      'url': 'https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%BC%E3%83%90%E3%83%BC%E3%83%80%E3%83%BC%E3%83%B3'},
#     'kawiki': {'badges': [],
#      'site': 'kawiki',
#      'title': 'აბადანი',
#      'url': 'https://ka.wikipedia.org/wiki/%E1%83%90%E1%83%91%E1%83%90%E1%83%93%E1%83%90%E1%83%9C%E1%83%98'},
#     'kowiki': {'badges': [],
#      'site': 'kowiki',
#      'title': '아바단',
#      'url': 'https://ko.wikipedia.org/wiki/%EC%95%84%EB%B0%94%EB%8B%A8'},
#     'ltwiki': {'badges': [],
#      'site': 'ltwiki',
#      'title': 'Abadanas',
#      'url': 'https://lt.wikipedia.org/wiki/Abadanas'},
#     'lvwiki': {'badges': [],
#      'site': 'lvwiki',
#      'title': 'Ābadāna',
#      'url': 'https://lv.wikipedia.org/wiki/%C4%80bad%C4%81na'},
#     'mgwiki': {'badges': [],
#      'site': 'mgwiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://mg.wikipedia.org/wiki/Abadan,_Iran'},
#     'nlwiki': {'badges': [],
#      'site': 'nlwiki',
#      'title': 'Abadan',
#      'url': 'https://nl.wikipedia.org/wiki/Abadan'},
#     'nnwiki': {'badges': [],
#      'site': 'nnwiki',
#      'title': 'Abadan',
#      'url': 'https://nn.wikipedia.org/wiki/Abadan'},
#     'nowiki': {'badges': [],
#      'site': 'nowiki',
#      'title': 'Abadan',
#      'url': 'https://no.wikipedia.org/wiki/Abadan'},
#     'pawiki': {'badges': [],
#      'site': 'pawiki',
#      'title': 'ਆਬਾਦਾਨ',
#      'url': 'https://pa.wikipedia.org/wiki/%E0%A8%86%E0%A8%AC%E0%A8%BE%E0%A8%A6%E0%A8%BE%E0%A8%A8'},
#     'plwiki': {'badges': [],
#      'site': 'plwiki',
#      'title': 'Abadan',
#      'url': 'https://pl.wikipedia.org/wiki/Abadan'},
#     'plwikivoyage': {'badges': [],
#      'site': 'plwikivoyage',
#      'title': 'Abadan',
#      'url': 'https://pl.wikivoyage.org/wiki/Abadan'},
#     'pnbwiki': {'badges': [],
#      'site': 'pnbwiki',
#      'title': 'آبادان',
#      'url': 'https://pnb.wikipedia.org/wiki/%D8%A2%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'ptwiki': {'badges': [],
#      'site': 'ptwiki',
#      'title': 'Abadan',
#      'url': 'https://pt.wikipedia.org/wiki/Abadan'},
#     'ptwikivoyage': {'badges': [],
#      'site': 'ptwikivoyage',
#      'title': 'Abadan',
#      'url': 'https://pt.wikivoyage.org/wiki/Abadan'},
#     'rowiki': {'badges': [],
#      'site': 'rowiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://ro.wikipedia.org/wiki/Abadan,_Iran'},
#     'ruwiki': {'badges': [],
#      'site': 'ruwiki',
#      'title': 'Абадан',
#      'url': 'https://ru.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'scowiki': {'badges': [],
#      'site': 'scowiki',
#      'title': 'Abadan',
#      'url': 'https://sco.wikipedia.org/wiki/Abadan'},
#     'shwiki': {'badges': [],
#      'site': 'shwiki',
#      'title': 'Abadan',
#      'url': 'https://sh.wikipedia.org/wiki/Abadan'},
#     'simplewiki': {'badges': [],
#      'site': 'simplewiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://simple.wikipedia.org/wiki/Abadan,_Iran'},
#     'skwiki': {'badges': [],
#      'site': 'skwiki',
#      'title': 'Ábádán',
#      'url': 'https://sk.wikipedia.org/wiki/%C3%81b%C3%A1d%C3%A1n'},
#     'slwiki': {'badges': [],
#      'site': 'slwiki',
#      'title': 'Abadan',
#      'url': 'https://sl.wikipedia.org/wiki/Abadan'},
#     'sqwiki': {'badges': [],
#      'site': 'sqwiki',
#      'title': 'Abadan',
#      'url': 'https://sq.wikipedia.org/wiki/Abadan'},
#     'srwiki': {'badges': [],
#      'site': 'srwiki',
#      'title': 'Абадан',
#      'url': 'https://sr.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'svwiki': {'badges': [],
#      'site': 'svwiki',
#      'title': 'Abadan',
#      'url': 'https://sv.wikipedia.org/wiki/Abadan'},
#     'tgwiki': {'badges': [],
#      'site': 'tgwiki',
#      'title': 'Ободон',
#      'url': 'https://tg.wikipedia.org/wiki/%D0%9E%D0%B1%D0%BE%D0%B4%D0%BE%D0%BD'},
#     'tlwiki': {'badges': [],
#      'site': 'tlwiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://tl.wikipedia.org/wiki/Abadan,_Iran'},
#     'trwiki': {'badges': [],
#      'site': 'trwiki',
#      'title': 'Abadan',
#      'url': 'https://tr.wikipedia.org/wiki/Abadan'},
#     'ukwiki': {'badges': [],
#      'site': 'ukwiki',
#      'title': 'Абадан',
#      'url': 'https://uk.wikipedia.org/wiki/%D0%90%D0%B1%D0%B0%D0%B4%D0%B0%D0%BD'},
#     'urwiki': {'badges': [],
#      'site': 'urwiki',
#      'title': 'آبادان',
#      'url': 'https://ur.wikipedia.org/wiki/%D8%A2%D8%A8%D8%A7%D8%AF%D8%A7%D9%86'},
#     'uzwiki': {'badges': [],
#      'site': 'uzwiki',
#      'title': 'Obodon',
#      'url': 'https://uz.wikipedia.org/wiki/Obodon'},
#     'viwiki': {'badges': [],
#      'site': 'viwiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://vi.wikipedia.org/wiki/Abadan,_Iran'},
#     'warwiki': {'badges': [],
#      'site': 'warwiki',
#      'title': 'Abadan, Iran',
#      'url': 'https://war.wikipedia.org/wiki/Abadan,_Iran'},
#     'zhwiki': {'badges': [],
#      'site': 'zhwiki',
#      'title': '阿巴丹',
#      'url': 'https://zh.wikipedia.org/wiki/%E9%98%BF%E5%B7%B4%E4%B8%B9'}},
#    'title': 'Q63049',
#    'type': 'item'}}}

# %%
def get_wikidata_coordinates(url):
    """
    Takes a Wikidata json url and returns a pair of coordinates if they exist
    or a pair of Nones if no coordinates were found.
    """
    if pd.isnull(url):
        return None,None
    try:
        response = requests.get(url)
        print('Parsing {}'.format(url))
        data = response.json()
        for k,entity in data['entities'].items():
            for l,claim in entity['claims'].items():
                try:
                    for c in claim:
                        lat = c['mainsnak']['datavalue']['value']['latitude']
                        lon = c['mainsnak']['datavalue']['value']['longitude']
                    return lat, lon
                except:
                    continue
            return None, None
    except requests.exceptions.MissingSchema:
        print('{} is not a URL.'.format(url))
        return None,None
    except:
        return None,None

# %%
get_wikidata_coordinates(test)
# Out:
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q63049.json
# (30.35, 48.283333333333)

# %% [markdown]
# I forgot how to set two columns at once in Pandas, so I googled it and found [this stackoverflow question](http://stackoverflow.com/questions/16236684/apply-pandas-function-to-column-to-create-multiple-new-columns), and adapted the answer that I liked best (the third)
#
# Then I ran into errors with some of the wikidata urls not actually being urls somehow, so I had to catch that error, which I figured out how to do from [this stackoverflow discussion](http://stackoverflow.com/questions/16511337/correct-way-to-try-except-using-python-requests-module)

# %%
gaz['lat'],gaz['lon'] = zip(*gaz.wikidata_json.map(get_wikidata_coordinates))
# Out:
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q63049.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q34603.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q190948.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q480421.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q357784.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q175323.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q34615.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q212546.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q400362.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1012854.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q19566.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q421648.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q812759.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q170532.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3805.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3640.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q80561.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q6487.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q626165.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q180103.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q6528766.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q643695.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q193445.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1524.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1010949.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q4828406.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2879031.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1530.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q158604.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2880568.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q199723.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q812759.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q48195.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q25475.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q211828.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1741.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3711.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q192176.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q158928.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q246163.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q208006.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q849497.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q189546.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q200951.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1781.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q19660.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q19660.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q45942.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q45942.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q259253.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q40738.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q989883.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q199712.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2703598.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q157725.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q8077682.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q374365.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q206895.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q214938.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q689820.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q79880.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q173690.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q328153.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q238217.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q239097.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q613943.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3766.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1382440.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q43387.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q27136.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q812759.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q117181.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1013462.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q173690.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q168866.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q193190.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q311204.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q459.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q45779.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q216907.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q103011.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q19429.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q5627195.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q182299.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q210087.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1004584.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q159835.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q171031.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2308046.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q35997.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q35997.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q85.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q192961.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q167895.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q202195.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q199712.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q160544.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q179570.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q52603.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1018215.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q179570.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q31572.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q173310.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q686813.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q21197.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q145810.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q79857.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q576368.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q188894.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q172415.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q192980.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q262579.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q178405.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3856.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q237254.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q193190.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q240504.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q157246.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q223587.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q101625.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q134703.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q35484.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q5806.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q178663.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q134291.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q526822.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q545707.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q174060.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3777059.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q642810.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q102397.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2308046.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q998805.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q93347.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q216912.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q214178.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q202337.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q38811.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q41572.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q915429.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q181379.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q963947.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q205432.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q133123.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2674278.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q990298.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q210205.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q187938.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q4656.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1004432.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q25270.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q851077.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3692.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q201101.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q188731.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q202458.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q133118.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q160173.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q170287.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q748832.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3766.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q160450.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2471.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q11194.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q147089.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q163490.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q289693.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1012854.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q31350.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q650630.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q19566.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q107401.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q7525.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q216897.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q472.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q605105.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q4703239.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q156053.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q129352.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q328647.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q181830.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q180717.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q466216.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q182640.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q271771.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q80053.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q220049.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2733823.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q994.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q83404.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q277201.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q159818.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q5475.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q546.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q193409.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q174684.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q309475.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q133118.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q179665.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q276362.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q605562.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q853527.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2028.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q5239.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1741.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q557754.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2456798.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q8049492.json
# ياش is not a URL.
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q3646.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q131290.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q6528766.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q178405.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1736413.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q1010949.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q210292.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q138986.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q140304.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q146699.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q2664842.json
# Parsing https://www.wikidata.org/wiki/Special:EntityData/Q204475.json

# %%
gaz.to_csv('osmanli-yer-adlari-with-coords.tsv',sep='\t',)
